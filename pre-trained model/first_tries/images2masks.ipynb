# %%
import pandas as pd
import numpy as np
import cv2
import numpy as np
from matplotlib import pyplot as plt
from scipy import ndimage
from skimage import measure, color, io

# to read multiple images
import glob
import cv2

# %%
path = r"C:\Users\sotka\Desktop\exam_projects\Data_Engineer-candidate_assessment_CellVoyant\TrainVal/*.*"
file_list = glob.glob(path) #Rerurns a list of file names
print(file_list)  #Prints the list containing file names

#Now let us load each file at a time...
my_list=[]  #Empty list to store images from the folder.
for file in glob.glob(path):   #Iterate through each file in the list using for
    #print(file)     #just stop here to see all file names printed
    a= cv2.imread(file)  #now, we can read each file since we have the full path
    my_list.append(a)  #Create a list of images (not just file names but full images)
    
#View images from the stored list
from matplotlib import pyplot as plt
print(type(my_list[2]))
plt.imshow(my_list[2])  #View the 3rd image in the list.
# Out:
# ['C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-1.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-10.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-100.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-101.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-102.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-103.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-104.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-105.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-106.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-107.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-108.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-11.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-12.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-13.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-14.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-15.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-16.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-17.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-18.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-19.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-2.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-20.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-21.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-22.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-23.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-24.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-25.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-26.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-27.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-28.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-29.ome_8bit.tif', 'C:\\Users\\sotka\\Desktop\\exam_projects\\Data_Engineer-candidate_assessment_CellVoyant\\TrainVal\\E10_10-3.ome_8bit ...
# <class 'numpy.ndarray'>

# %%
def img2mask(image):
    
    import pandas as pd
    import numpy as np
    import cv2
    import numpy as np
    from matplotlib import pyplot as plt
    from scipy import ndimage
    from skimage import measure, color, io
    # to read multiple images
    import glob
    
    #img = cv2.imread(image)

    #Extract only blue channel as DAPI / nuclear (blue) staining is the best
    #channel to perform cell count.
    cells=img[:,:,0]  #Blue channel. Image equivalent to grey image.

    pixels_to_um = 0.454 # 1 pixel = 454 nm (got this from the metadata of original image)

    #Threshold image to binary using OTSU. ALl thresholded pixels will be set to 255
    ret1, thresh = cv2.threshold(cells, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)


    # Morphological operations to remove small noise - opening
    #To remove holes we can use closing
    kernel = np.ones((3,3),np.uint8)
    opening = cv2.morphologyEx(thresh,cv2.MORPH_OPEN,kernel, iterations = 2)

    from skimage.segmentation import clear_border
    opening = clear_border(opening) #Remove edge touching grains
    #Check the total regions found before and after applying this. 

    #Now we know that the regions at the center of cells is for sure cells
    #The region far away is background.
    #We need to extract sure regions. For that we can use erode. 
    #But we have cells touching, so erode alone will not work. 
    #To separate touching objects, the best approach would be distance transform and then thresholding.

    # let us start by identifying sure background area
    # dilating pixes a few times increases cell boundary to background. 
    # This way whatever is remaining for sure will be background. 
    #The area in between sure background and foreground is our ambiguous area. 
    #Watershed should find this area for us. 
    sure_bg = cv2.dilate(opening,kernel,iterations=5)

    #cv2.imshow('Sure Background', sure_bg)
    #cv2.waitKey(0)

    # Finding sure foreground area using distance transform and thresholding
    #intensities of the points inside the foreground regions are changed to 
    #distance their respective distances from the closest 0 value (boundary).
    #https://www.tutorialspoint.com/opencv/opencv_distance_transformation.htm
    dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,5)


    #Let us threshold the dist transform by starting at 1/2 its max value.
    #print(dist_transform.max()) gives about 21.9
    ret2, sure_fg = cv2.threshold(dist_transform,0.25*dist_transform.max(),255,0)

    #Later you realize that 0.25* max value will not separate the cells well.
    #High value like 0.7 will not recognize some cells. 0.5 seems to be a good compromize

    # Unknown ambiguous region is nothing but bkground - foreground
    sure_fg = np.uint8(sure_fg)
    #cv2.imshow('Sure fg', sure_fg)
    #cv2.waitKey(0)
    unknown = cv2.subtract(sure_bg,sure_fg)

    #Now we create a marker and label the regions inside. 
    # For sure regions, both foreground and background will be labeled with positive numbers.
    # Unknown regions will be labeled 0. 
    #For markers let us use ConnectedComponents. 
    ret3, markers = cv2.connectedComponents(sure_fg)

    #One problem rightnow is that the entire background pixels is given value 0.
    #This means watershed considers this region as unknown.
    #So let us add 10 to all labels so that sure background is not 0, but 10
    markers = markers+10

    # Now, mark the region of unknown with zero
    markers[unknown==255] = 0
    #plt.imshow(markers, cmap='jet')   #Look at the 3 distinct regions.

    #Now we are ready for watershed filling. 
    markers = cv2.watershed(img,markers)
    #The boundary region will be marked -1
    #https://docs.opencv.org/3.3.1/d7/d1b/group__imgproc__misc.html#ga3267243e4d3f95165d55a618c65ac6e1

    #Let us color boundaries. 
    img[markers == -1] = [255,255,255]  

    img[markers != -1] = [0,0,0]
       
    return img

# %%
# converting images to masks via a custom function
masks = []
for img in file_list:
    img = cv2.imread(img)
    img = img2mask(img)
    masks.append(img)

print(type(masks[0]))
plt.imshow(masks[0])
# Out:
# <class 'numpy.ndarray'>

# %%
# short version of the image names
short_names = [name.split('\\')[-1] for name in file_list]
short_names = [name.split('.')[0] for name in short_names]
print(short_names)
# Out:
# ['E10_10-1', 'E10_10-10', 'E10_10-100', 'E10_10-101', 'E10_10-102', 'E10_10-103', 'E10_10-104', 'E10_10-105', 'E10_10-106', 'E10_10-107', 'E10_10-108', 'E10_10-11', 'E10_10-12', 'E10_10-13', 'E10_10-14', 'E10_10-15', 'E10_10-16', 'E10_10-17', 'E10_10-18', 'E10_10-19', 'E10_10-2', 'E10_10-20', 'E10_10-21', 'E10_10-22', 'E10_10-23', 'E10_10-24', 'E10_10-25', 'E10_10-26', 'E10_10-27', 'E10_10-28', 'E10_10-29', 'E10_10-3', 'E10_10-30', 'E10_10-31', 'E10_10-32', 'E10_10-33', 'E10_10-34', 'E10_10-35', 'E10_10-36', 'E10_10-37', 'E10_10-38', 'E10_10-39', 'E10_10-4', 'E10_10-40', 'E10_10-41', 'E10_10-42', 'E10_10-43', 'E10_10-44', 'E10_10-45', 'E10_10-46', 'E10_10-47', 'E10_10-48', 'E10_10-49', 'E10_10-5', 'E10_10-50', 'E10_10-51', 'E10_10-52', 'E10_10-53', 'E10_10-54', 'E10_10-55', 'E10_10-56', 'E10_10-57', 'E10_10-58', 'E10_10-59', 'E10_10-6', 'E10_10-60', 'E10_10-61', 'E10_10-62', 'E10_10-63', 'E10_10-64', 'E10_10-65', 'E10_10-66', 'E10_10-67', 'E10_10-68', 'E10_10-69', 'E10_10-7', 'E10_10-70', 'E10_10-71', 'E10_10-72', 'E10_10-73', 'E10_10-74', 'E10_10-75', 'E10_10-76', 'E10_10-77', 'E10_10-78', 'E10_10-79', 'E10_10-8', 'E10_10-80', 'E10_10-81', 'E10_10-82', 'E10_10-83', 'E10_10-84', 'E10_10-85', 'E10_10-86', 'E10_10-87', 'E10_10-88', 'E10_10-89', 'E10_10-9', 'E10_10-90', 'E10_10-91', 'E10_10-92', 'E10_10-93', 'E10_10-94', 'E10_10-95', 'E10_10-96', 'E10_10-97', 'E10_10-98', 'E10_10-99', 'E11_11-100', 'E11_11-101', 'E11_11-102', 'E11_11-103', 'E11_11-104', 'E11_11-105', 'E11_11-106', 'E11_11-107', 'E11_11-108', 'E11_11-21', 'E11_11-22', 'E11_11-23', 'E11_11-24', 'E11_11-25', 'E11_11-26', 'E11_11-27', 'E11_11-28', 'E11_11-29', 'E11_11-30', 'E11_11-31', 'E11_11-32', 'E11_11-33', 'E11_11-34', 'E11_11-35', 'E11_11-36', 'E11_11-37', 'E11_11-38', 'E11_11-39', 'E11_11-40', 'E11_11-41', 'E11_11-42', 'E11_11-43', 'E11_11-44', 'E11_11-45', 'E11_11-46', 'E11_11-47', 'E11_11-48', 'E11_11-49', 'E11_11-50', 'E11_11-51', 'E11_11-52', 'E11_11-53', 'E11_11-54', 'E11_11-55', 'E11_11-56', 'E11_11-57', 'E11_11-58', 'E11_11-59', 'E11_11-60', 'E11_11-61', 'E11_11-62', 'E11_11-63', 'E11_11-64', 'E11_11-65', 'E11_11-66', 'E11_11-67', 'E11_11-68', 'E11_11-69', 'E11_11-70', 'E11_11-71', 'E11_11-72', 'E11_11-73', 'E11_11-74', 'E11_11-75', 'E11_11-76', 'E11_11-77', 'E11_11-78', 'E11_11-79', 'E11_11-80', 'E11_11-81', 'E11_11-82', 'E11_11-83', 'E11_11-84', 'E11_11-85', 'E11_11-86', 'E11_11-87', 'E11_11-88', 'E11_11-89', 'E11_11-90', 'E11_11-91', 'E11_11-92', 'E11_11-93', 'E11_11-94', 'E11_11-95', 'E11_11-96', 'E11_11-97', 'E11_11-98', 'E11_11-99']

# %%
# save to file
import os.path

output_path = r'C:\Users\sotka\Desktop\exam_projects\Data_Engineer-candidate_assessment_CellVoyant\TrainVal_Masks'

i = 0
for mask in masks:
    cv2.imwrite(os.path.join(output_path, short_names[i]+'_mask.tif'), mask)
    i += 1
