# %%
import matplotlib.pyplot as plt
import numpy as np

img = plt.imread(r"C:\Users\sotka\Desktop\CellVoyant_Results\pre-trained model\Test_Layered\E11_11-1_layered.tif") # your image
y = 853.3241922120961
x = 1039.8081193040596
size = 50 # size of marker

plt.imshow(img, cmap="gray") # plot image
plt.scatter(x, y, size, c="r", marker="+") # plot markers
plt.show()
